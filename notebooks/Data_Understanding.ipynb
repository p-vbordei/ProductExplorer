# %% [markdown]
# ## Memory Testing

# %% [markdown]
# ------------------
# #### PRODUCTS DATA
#
# **Step 1: Scrape Data**
#
# - Raw Product Data
#
#
# **Step 2: Extract**
#
# Data_Products_step_2_extraction
#
# *Input:* `products.csv`
#
# *Output:* `products_enhanced.csv`
#
#
# **Step 3: Gather Insights that describe One Product**
#
# Data_Products_step_3_insights
#
# *Input:* `products_enhanced.csv`
#
# *Output:* `summarised_product_information.json`
#
#
# **Step 4: Present the data**
#
# DASH_Product_text_descriptors

# %%
## products.csv
import pandas as pd
import json

products = pd.read_csv('products.csv')
print(products.shape)
print(products.columns)
products.head(3)
# Out:
# (12, 43)
# Index(['title', 'description', 'feature_bullets', 'variants', 'categories',
#        'asin', 'url', 'reviews.total_reviews', 'reviews.rating',
#        'reviews.answered_questions', 'item_available', 'price.symbol',
#        'price.currency', 'price.current_price', 'price.discounted',
#        'price.before_price', 'price.savings_amount', 'price.savings_percent',
#        'bestsellers_rank', 'main_image', 'total_images', 'images',
#        'total_videos', 'videos', 'delivery_message',
#        'product_information.dimensions', 'product_information.weight',
#        'product_information.available_from',
#        'product_information.available_from_utc',
#        'product_information.available_for_months',
#        'product_information.available_for_days',
#        'product_information.manufacturer', 'product_information.model_number',
#        'product_information.department', 'product_information.qty_per_order',
# ...

# %%
products_enhanced = pd.read_csv('products_enhanced.csv')
print(products_enhanced.shape)
print(products_enhanced.columns)
print("The new columns are:",set(products_enhanced.columns) - set(products.columns))
print(dict(products_enhanced.dtypes))
products_enhanced.head(3)
# Out:
# (12, 44)
# Index(['title', 'description', 'feature_bullets', 'variants', 'categories',
#        'asin', 'url', 'reviews.total_reviews', 'reviews.rating',
#        'reviews.answered_questions', 'item_available', 'price.symbol',
#        'price.currency', 'price.current_price', 'price.discounted',
#        'price.before_price', 'price.savings_amount', 'price.savings_percent',
#        'bestsellers_rank', 'main_image', 'total_images', 'images',
#        'total_videos', 'videos', 'delivery_message',
#        'product_information.dimensions', 'product_information.weight',
#        'product_information.available_from',
#        'product_information.available_from_utc',
#        'product_information.available_for_months',
#        'product_information.available_for_days',
#        'product_information.manufacturer', 'product_information.model_number',
#        'product_information.department', 'product_information.qty_per_order',
# ...

# %%
products_enhanced.main_image[3]
# Out:
# 'https://m.media-amazon.com/images/I/71YisamwS0L._AC_SL1500_.jpg'

# %%
with open('/Users/vladbordei/Documents/Development/oaie2/summarised_product_information.json') as file:
    json_string = file.read()
    data = json.loads(json_string)

    print(data.keys())
    print(data['product_summary_dict'])
# Out:
# dict_keys(['product_summary_dict', 'what_is_in_the_box_dict', 'technical_facts_dict', 'features_dict', 'how_product_use_dict', 'where_product_use_dict', 'user_description_dict'])
# {'Product Summary': 'These magnetic drawing boards offer a mess-free and creative play experience for children, promoting problem-solving, hand-eye coordination, and imagination. They feature magnetized beads and a stylus pen for easy drawing and erasing, and are made of child-safe, non-toxic, BPA-free, and lead-free materials. Some boards are portable and travel-friendly, making them great companions for long drives and trips. Some boards also offer a tactile drawing experience and help children learn and write the alphabet correctly. These boards are suitable for both home and classroom use, and make great gifts for toddlers and children.', 'Outliers': 'There are no outliers in this list.'}

# %% [markdown]
# --------------------
# #### REVIEWS DATA
#
# **Step 1: Scrape Data**
#
# - Raw Reviews Data
#
#
# **Step 2: Extract Information from Reviews**
#
# Data_Reviews_step_2_extraction
#
# *Input:* `reviews_with_sentiment.csv`
#
# *Output:* `reviews_db.csv`
#
#
# **Step 3: Functions to Gather Traits**
#
# Data_Reviews_step_3_insights
#
#
#
# **Step 4: Export and save Traits**
#
# Data_Reviews_step_4_df_saving
#
# *Input:* `reviews_db.csv`
#
# *Output:* `weighted_key_data_df_heatmap.csv`
#
# *Output:* `weighted_key_data_df_graph.csv`
#
#
#
# **Step 5: Present the data**
#
# DASH_Reviews_HeatmapChat

# %%
reviews = pd.read_csv('reviews_with_sentiment.csv')
print(reviews.shape)
print(reviews.columns)
reviews.head(3)
# Out:
# (1072, 14)
# Index(['id', 'asin.original', 'asin.variant', 'review_data', 'date.date',
#        'date.unix', 'name', 'rating', 'title', 'review', 'verified_purchase',
#        'media', 'positive_sentiment', 'negative_sentiment'],
#       dtype='object')
#                id asin.original asin.variant  \
# 0   R2VHEASLT4JXP    B07X7YFZWG   B07X7YFZWG
# 1  R25XJC37QWHNUF    B07X7YFZWG   B07XCRT49W
# 2  R38KJMV9WJB5HE    B07X7YFZWG   B07XCRT49W
#
#                                          review_data          date.date  \
# 0  Reviewed in the United States 🇺🇸 on December 3...  December 30, 2022
# 1  Reviewed in the United States 🇺🇸 on December 2...  December 29, 2022
# 2  Reviewed in the United States 🇺🇸 on December 2...  December 26, 2022
#
#     date.unix            name  rating                               title  \
# 0  1672358400     kevin bauer       5                        Perfect gift
# 1  1672272000    Dragonbear82       4  Fun for fidde toy or for car rides
# ...

# %%
reviews_db = pd.read_csv('reviews_db.csv')
print(reviews_db.shape)
print(reviews_db.columns)
print("The new columns are:",set(reviews_db.columns) - set(reviews.columns))
reviews_db.head(3)
# Out:
# (410, 26)
# Index(['rating', 'review_summary', 'observed_technical_facts',
#        'positive_sentiment', 'negative_sentiment', 'improvements_expected',
#        'issues_identified', 'how_product_is_used', 'media',
#        'where_product_is_used', 'sentiment', 'anger', 'anger_reason',
#        'delight', 'delight_reason', 'disappointment', 'disappointment_reason',
#        'time', 'season', 'weather', 'user_description', 'title', 'review',
#        'asin.variant', 'id', 'asin.original'],
#       dtype='object')
# The new columns are: {'weather', 'improvements_expected', 'observed_technical_facts', 'delight_reason', 'disappointment_reason', 'delight', 'season', 'where_product_is_used', 'user_description', 'issues_identified', 'anger', 'sentiment', 'time', 'anger_reason', 'disappointment', 'review_summary', 'how_product_is_used'}
#    rating                                     review_summary  \
# 0       5  Great product for young children, perfect for ...
# ...

# %%
weighted_improvements_expected_df_heatmap = pd.read_csv('weighted_improvements_expected_df_heatmap.csv')
print(weighted_improvements_expected_df_heatmap.shape)
print(weighted_improvements_expected_df_heatmap.columns)
weighted_improvements_expected_df_heatmap.head(3)
# Out:
# (133, 13)
# Index(['asin.original', 'data_label', 'positive_sentiment',
#        'negative_sentiment', 'rating', 'id', 'how_product_is_used', 'media',
#        'where_product_is_used', 'user_description', 'observation_count',
#        'percentage', 'type'],
#       dtype='object')
#   asin.original                                         data_label  \
# 0    B01M4OV4Q4  clear communication about item condition and i...
# 1    B01M4OV4Q4         improved magnet strength and functionality
# 2    B01M4OV4Q4         improved noise level for quieter operation
#
#    positive_sentiment  negative_sentiment rating     id  \
# 0            0.199387            0.518820    [3]  [395]
# 1            0.044469            0.637204    [3]  [404]
# 2            0.946954            0.002356    [4]  [400]
#
#                     how_product_is_used media where_product_is_used  \
# 0                           ['Unknown']    []           ['Unknown']
# ...

# %%
weighted_improvements_expected_df_graph = pd.read_csv('weighted_improvements_expected_df_graph.csv')
print(weighted_improvements_expected_df_graph.shape)
print(weighted_improvements_expected_df_graph.columns)
weighted_improvements_expected_df_graph.head(3)
# Out:
# (133, 13)
# Index(['data_label', 'positive_sentiment', 'negative_sentiment', 'rating',
#        'id', 'how_product_is_used', 'media', 'where_product_is_used',
#        'user_description', 'asin.original', 'observation_count', 'rating_avg',
#        'type'],
#       dtype='object')
#                          data_label  positive_sentiment  negative_sentiment  \
# 0  added lanyard attachment for pen            0.937835            0.004944
# 1  added lanyard attachment for pen            0.937835            0.004944
# 2  added lanyard attachment for pen            0.937835            0.004944
#
#       rating              id      how_product_is_used media  \
# 0  [5, 5, 5]  [176, 336, 51]  ['Drawing and writing']    []
# 1  [5, 5, 5]  [176, 336, 51]  ['Drawing and writing']    []
# 2  [5, 5, 5]  [176, 336, 51]  ['Drawing and writing']    []
#
#   where_product_is_used                               user_description  \
# ...

# %%
weighted_issues_identified_df_heatmap = pd.read_csv('weighted_issues_identified_df_heatmap.csv')
print(weighted_issues_identified_df_heatmap.shape)
print(weighted_issues_identified_df_heatmap.columns)
weighted_issues_identified_df_heatmap.head(3)
# Out:
# (164, 13)
# Index(['asin.original', 'data_label', 'positive_sentiment',
#        'negative_sentiment', 'rating', 'id', 'how_product_is_used', 'media',
#        'where_product_is_used', 'user_description', 'observation_count',
#        'percentage', 'type'],
#       dtype='object')
#   asin.original                                 data_label  \
# 0    B01M4OV4Q4  losing the pen renders the device useless
# 1    B01M4OV4Q4          magnet board not working properly
# 2    B01M4OV4Q4                        no issues mentioned
#
#    positive_sentiment  negative_sentiment     rating               id  \
# 0            0.820581            0.019927        [4]            [408]
# 1            0.044469            0.637204        [3]            [404]
# 2            0.774805            0.067732  [5, 5, 5]  [403, 396, 397]
#
#                                  how_product_is_used  \
# 0                                        ['Unknown']
# 1                 ['Pediatric occupational therapy']
# ...

# %%
weighted_issues_identified_df_graph = pd.read_csv('weighted_issues_identified_df_graph.csv')
print(weighted_issues_identified_df_graph.shape)
print(weighted_issues_identified_df_graph.columns)
weighted_issues_identified_df_graph.head(3)
# Out:
# (164, 13)
# Index(['data_label', 'positive_sentiment', 'negative_sentiment', 'rating',
#        'id', 'how_product_is_used', 'media', 'where_product_is_used',
#        'user_description', 'asin.original', 'observation_count', 'rating_avg',
#        'type'],
#       dtype='object')
#                                data_label  positive_sentiment  \
# 0  balls may be defective and not stay up            0.028913
# 1  balls may be defective and not stay up            0.028913
# 2                   balls may malfunction            0.726388
#
#    negative_sentiment     rating              id how_product_is_used  \
# 0            0.717211     [2, 2]      [118, 238]  ['Playing a game']
# 1            0.717211     [2, 2]      [118, 238]  ['Playing a game']
# 2            0.023107  [4, 4, 4]  [26, 331, 141]                  []
#
#                                                media where_product_is_used  \
# 0                                                 []                    []
# ...

# %%
weighted_issues_identified_df_graph[weighted_issues_identified_df_graph['data_label'] == 'product is not working and the pen attachment is not pulling up magnets']
# Out:
#                                             data_label  positive_sentiment  \
# 141  product is not working and the pen attachment ...            0.000743
# 142  product is not working and the pen attachment ...            0.000743
#
#      negative_sentiment  rating          id how_product_is_used media  \
# 141            0.993713  [1, 1]  [248, 113]                  []    []
# 142            0.993713  [1, 1]  [248, 113]                  []    []
#
#     where_product_is_used user_description asin.original  observation_count  \
# 141                    []               []    B085Q4W3WX                  2
# 142                    []               []    B09R9MMW6J                  2
#
#      rating_avg   type
# 141           1  Issue
# 142           1  Issue

# %%
from sqlalchemy import create_engine
# Create an SQLAlchemy engine to connect to the database
engine = create_engine('postgresql://postgres:mysecretpassword@localhost/postgres')

# %%
asin_list = ['B085Q4W3WX', 'B09R9MMW6J']
id_list = [248, 113]
params = asin_list + id_list
query = f"""
        SELECT asin_variant, rating, review_summary, review
        FROM reviews 
        WHERE asin IN ({','.join(['%s']*len(asin_list))})
        AND id IN ({','.join(['%s']*len(id_list))})
        """
selected_data =  pd.read_sql_query(query, engine, params=params)
selected_data
# Out:
#   asin_variant  rating                              review_summary  \
# 0   B085Q4W3WX       1  Poor product quality, pen attachment issue
# 1   B085Q4W3WX       1  Poor product quality, pen attachment issue
#
#                                               review
# 0  Product doesnt work Poor product quality Dont ...
# 1  Product doesnt work Poor product quality Dont ...

# %%
weighted_issues_identified_df_graph['data_label'].value_counts()
# Out:
# no issues mentioned                                                                  9
# beads can get stuck                                                                  4
# too loud for use on long journeys                                                    3
# is loud                                                                              3
# not suitable for all users                                                           3
#                                                                                     ..
# limited hole pattern for creating perfect designs                                    1
# kids were not interested and the loud volume was annoying for others on the plane    1
# kids were not interested and it was annoying for others on the plane                 1
# pen is not attached and easily lost                                                  1
# makes an annoying clicking noise                                                     1
# ...

# %%
weighted_product_facts_df_heatmap = pd.read_csv('weighted_product_facts_df_heatmap.csv')
print(weighted_product_facts_df_heatmap.shape)
print(weighted_product_facts_df_heatmap.columns)
weighted_product_facts_df_heatmap.head(3)
# Out:
# (144, 13)
# Index(['asin.original', 'data_label', 'positive_sentiment',
#        'negative_sentiment', 'rating', 'id', 'how_product_is_used', 'media',
#        'where_product_is_used', 'user_description', 'observation_count',
#        'percentage', 'type'],
#       dtype='object')
#   asin.original                                         data_label  \
# 0    B01M4OV4Q4           magnetic board for hand-eye coordination
# 1    B01M4OV4Q4    magnetic board with metal rods and attached pen
# 2    B01M4OV4Q4  metal beads that move around and make shaking ...
#
#    positive_sentiment  negative_sentiment rating     id  \
# 0            0.044469            0.637204    [3]  [404]
# 1            0.983954            0.003293    [5]  [396]
# 2            0.946954            0.002356    [4]  [400]
#
#                     how_product_is_used media where_product_is_used  \
# 0    ['Pediatric occupational therapy']    []           ['Unknown']
# ...

# %%
weighted_product_facts_df_graph = pd.read_csv('weighted_product_facts_df_graph.csv')
print(weighted_product_facts_df_graph.shape)
print(weighted_product_facts_df_graph.columns)
weighted_product_facts_df_graph.head(3)
# Out:
# (144, 13)
# Index(['data_label', 'positive_sentiment', 'negative_sentiment', 'rating',
#        'id', 'how_product_is_used', 'media', 'where_product_is_used',
#        'user_description', 'asin.original', 'observation_count', 'rating_avg',
#        'type'],
#       dtype='object')
#                       data_label  positive_sentiment  negative_sentiment  \
# 0            balls are defective            0.028913            0.717211
# 1            balls are defective            0.028913            0.717211
# 2  balls do not fall down easily            0.169602            0.276580
#
#    rating          id      how_product_is_used media where_product_is_used  \
# 0  [2, 2]  [118, 238]       ['Playing a game']    []                    []
# 1  [2, 2]  [118, 238]       ['Playing a game']    []                    []
# 2     [3]       [276]  ['Drawing and writing']    []                    []
#
#   user_description asin.original  observation_count  rating_avg  type
# ...

# %% [markdown]
# #### DATA ARCHITECTURE SCOPE
#
# EDGES
# - Product to feature. Weight: # Observations
# - Product to user. Weight: # Observations
# - Product to issue. Weight: # Observations
# - Review to issue
# - Issue to solution
# - Review to Solution
# - Product to prototype
# - solution to prototype
#
#
#
# Trait: Size by Frequency  / toate ASINS
#
# 1 Trait poate fi conectat la mai multe ASINS

# %% [markdown]
# Datele pe Reviews trebuie procesate toate, mai bine.
# Care este cel mai bun mod de a salva datele?
# - Pentru a le putea arata per caracteristica in Heatmap (asa cum e acum)
# - Pentru a putea crea entitatile/ nodurile
# - Pentru a fi informatie pentru context in insertii ulterioare

# %% [markdown]
# #### SIMPLE APPROACH
#
# I would like to create the following dataframes
#
# Node : <'issues_identified' >
#
# Proprieties:
#
# {'Node_id',
# 'ASINS List'
# 'Reviews_IDs'
# 'Number of Observations'
# 'Weighted Rating'
# 'Weighted Positive Sentiment'
# 'Weighted Negative Sentiment'
# 'user_description',
# 'how_product_is_used',
# 'where_product_is_used',
# }
#
#
# Node : <'improvements_expected' >
#
# Proprieties:
#
# {'Node_id',
# 'ASINS List'
# 'Reviews_IDs'
# 'Number of Observations'
# 'Weighted Rating'
# 'Weighted Positive Sentiment'
# 'Weighted Negative Sentiment'
# 'user_description',
# 'how_product_is_used',
# 'where_product_is_used',
# }
#
# Node : <'product_facts' >
#
# Proprieties:
# {'Node_id',
# 'ASINS List'
# 'Reviews_IDs'
# 'Number of Observations'
# 'Weighted Rating'
# 'Weighted Positive Sentiment'
# 'Weighted Negative Sentiment'
# 'user_description',
# 'how_product_is_used',
# 'where_product_is_used',
# }

# %%
from sqlalchemy import create_engine

# Create an SQLAlchemy engine to connect to the database
engine = create_engine('postgresql://postgres:mysecretpassword@localhost/postgres')

# Read the ASIN values from the CSV file
asin_list = pd.read_csv('asin_list.csv')['asin'].tolist()

# Query the weighted_trait_graph table for the required data
query = f"""
    SELECT asin, data_label, cluster_label, type, rating_avg, rating, id, cluster_problem_statement, cluster_solution_1_title, cluster_solution_1_description, cluster_solution_2_title, cluster_solution_2_description, cluster_solution_3_title, cluster_solution_3_description
    FROM weighted_trait_graph 
    WHERE asin IN ({','.join(['%s']*len(asin_list))})
"""
weighted_trait_df_graph = pd.read_sql_query(query, engine, params=asin_list)
weighted_trait_df_graph['id'] = weighted_trait_df_graph['id'].map(eval)

# %%
cluster_solution_nodes = list(set(weighted_trait_df_graph['cluster_solution_1_title'])) + \
              list(set(weighted_trait_df_graph['cluster_solution_2_title'])) + \
              list(set(weighted_trait_df_graph['cluster_solution_3_title']))

cluster_solution_nodes = [item for item in cluster_solution_nodes if item != 'nan']
