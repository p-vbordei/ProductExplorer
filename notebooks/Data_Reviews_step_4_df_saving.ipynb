# %%
import pandas as pd
import numpy as np
from typing import Dict
import os
from dotenv import load_dotenv
import openai
import ast
from typing import List

load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if os.getenv("OPENAI_API_KEY") is not None:
    print ("OPENAI_API_KEY is ready")
else:
    print ("OPENAI_API_KEY environment variable not found")

from Data_Reviews_step_3_insights import get_weighted_results_heatmap
from Data_Reviews_step_3_insights import get_weighted_results_graph
from Data_Reviews_step_3_insights import process_data_short
from Data_Reviews_step_3_insights import process_list

from Data_reviews_traits_clustering_step_6 import run_clustering_script

# %%
import ast

def explode_data(dataframe, column_name):
    # Convert strings to lists

    for i in range(len(dataframe[column_name])):
        try:
            if isinstance(dataframe[column_name][i], str):
                dataframe[column_name][i] = ast.literal_eval(dataframe[column_name][i])   
        except:
            pass
    
    # Extract single values from lists
    dataframe[column_name] = dataframe[column_name].apply(lambda x: x[0] if isinstance(x, list) and len(x) == 1 else [x][0] if not isinstance(x, list) else x)

    # Explode the specified column
    dataframe = dataframe.explode(column_name)

    # Rename the column
    dataframe.rename(columns={column_name: 'key_data'}, inplace=True)

    # Replace missing values with NaN
    dataframe['key_data'].replace(['', 'NA', 'N/A', 'missing', 'NaN', 'unknown', 'Unknown', ['Unknown']], np.nan, inplace=True)

    # Drop NaN values
    dataframe.dropna(subset=['key_data'], inplace=True)

    # Replace missing values with 'Unknown'
    dataframe['key_data'].fillna(value='unknown', inplace=True)

    # Drop 'Unknown' values
    dataframe = dataframe[dataframe['key_data'] != 'unknown']

    # Get value counts and sort values
    value_counts = dataframe['key_data'].value_counts()
    key_data_list = sorted(list(set(dataframe['key_data'])))

    dataframe.reset_index(inplace=True, drop=True)
    
    return dataframe, key_data_list


# %%
def get_chatbot_responses(key_data_list, batch_size=80, temperature=0.2,api_key=OPENAI_API_KEY):
    
    User_Prompt_1 = """
    ```Input List:``` ['cleaning','cleaning ease','adjustability' ,'adjustability of forks','adjustable length']
    """

    AI_Prompt_1 = """{
    'cleaning' : 'easy to clean',
    'cleaning ease': 'easy to clean',
    'adjustability' : 'length is adjustable',
    'adjustability of forks': 'length is adjustable',
    'adjustable length': 'length is adjustable',
    }"""

    chatbot_responses = {}
    for i in range(0, len(key_data_list), batch_size):
        # Get the current batch of up to batch_size items
        batch = key_data_list[i:i+batch_size]
        User_Prompt_2 = f"```Input List:``` {batch}"

        # Send the prompt to the chatbot and get the response
        response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo",
                    messages=[
                        {"role": "user", "content": User_Prompt_1},
                        {"role": "assistant", "content": AI_Prompt_1},
                        {"role": "user", "content": User_Prompt_2} ],
                    temperature=0.2,
                    api_key=api_key
        )
    
        # Process the response and store in the dictionary
        chatbot_responses[i] = response["choices"][0]["message"]["content"]
        print(chatbot_responses[i])
    
    return chatbot_responses

# %%
def stick_together_dictionaries(placeholder_dict):
    merged_dict = {}
    for key in placeholder_dict.keys():
        dict_obj = eval(placeholder_dict[key])
        merged_dict.update(dict_obj)

    return merged_dict

# Remove 'Unknown' values and eliminate duplicates
def process_list(column_data):
    return list(set(x for x in column_data if x != 'Unknown'))


# %%


def get_weighted_results_heatmap(dataframe, data_column_name, aisin_column):
    
    dataframe['positive_sentiment'] = dataframe['positive_sentiment'].astype(float)
    dataframe['negative_sentiment'] = dataframe['negative_sentiment'].astype(float)

    # Apply ast.literal_eval() to relevant columns before aggregation
    for column_name in ['how_product_is_used', 'media', 'where_product_is_used', 'user_description']:
        dataframe[column_name] = dataframe[column_name].fillna('').apply(lambda elem: ast.literal_eval(elem) if isinstance(elem, str) and elem.startswith('[') else [elem] if isinstance(elem, str) else elem)
    
    # Allocate sentiment to main_improvement_iter_2 by ASIN and aggregate
    agg_result = dataframe.groupby([aisin_column, data_column_name]).agg({
        'positive_sentiment': 'mean',
        'negative_sentiment': 'mean',
        'rating': lambda x: list(x),
        'id': lambda x: list(x),
        'how_product_is_used': lambda x: sum((lst for lst in x), []),
        'media': lambda x: sum((lst for lst in x), []),
        'where_product_is_used': lambda x: sum((lst for lst in x), []),
        'user_description': lambda x: sum((lst for lst in x), [])
    }).reset_index()


    # Aggregate the count separately
    count_result = dataframe.groupby([aisin_column, data_column_name]).size().reset_index(name='observation_count')

    # Merge the aggregated count with the main result
    result = pd.merge(agg_result, count_result, on=[aisin_column, data_column_name])

    columns_to_process = ['id']
    for column in columns_to_process:
        result[column] = result[column].apply(process_list)

    # Calculate the sum of observation_count for each ASIN
    asin_observation_sum = result.groupby(aisin_column)['observation_count'].sum().to_dict()

    # Create a percentage column using the asin_observation_sum dictionary
    result['percentage'] = result.apply(lambda row: row['observation_count'] / asin_observation_sum[row[aisin_column]] * 100, axis=1)
    result.rename(columns={data_column_name: 'data_label'}, inplace=True)
    return result


def get_weighted_results_graph(dataframe, data_column_name, aisin_column):

    # Apply ast.literal_eval() to relevant columns before aggregation
    for column_name in ['how_product_is_used', 'media', 'where_product_is_used', 'user_description',aisin_column]:
        dataframe[column_name] = dataframe[column_name].fillna('').apply(lambda elem: ast.literal_eval(elem) if isinstance(elem, str) and elem.startswith('[') else [elem] if isinstance(elem, str) else elem)
    
    dataframe['positive_sentiment'] = dataframe['positive_sentiment'].astype(float)
    dataframe['negative_sentiment'] = dataframe['negative_sentiment'].astype(float)

    # Allocate sentiment to main_improvement_iter_2 by ASIN and aggregate
    agg_result = dataframe.groupby([data_column_name]).agg({
        'positive_sentiment': 'mean',
        'negative_sentiment': 'mean',
        'rating': lambda x: list(x),
        'id': lambda x: list(x),
        'how_product_is_used': lambda x: sum((lst for lst in x), []),
        'media': lambda x: sum((lst for lst in x), []),
        'where_product_is_used': lambda x: sum((lst for lst in x), []),
        'user_description': lambda x: sum((lst for lst in x), []),
        aisin_column: lambda x: sum((lst for lst in x), [])
    }).reset_index()

    # Aggregate the count separately
    count_result = dataframe.groupby([data_column_name]).size().reset_index(name='observation_count')

    # Merge the aggregated count with the main result
    result = pd.merge(agg_result, count_result, on=[data_column_name])

    m = []
    for e in result['rating']:
        f =[]
        for r in e:
            f.append(int(r))
        m.append(np.mean(f))
    k = []
    for e in m:
        f = round(e,0)
        f = int(f)
        k.append(f)

    result['rating_avg'] = k

    columns_to_process = ['id', 'how_product_is_used', 'media', 'where_product_is_used', 'user_description', aisin_column]
    for column in columns_to_process:
        result[column] = result[column].apply(process_list)

    result.rename(columns={data_column_name: 'data_label'}, inplace=True)
    return result


def process_data_short(file_path: str, key: str) -> pd.DataFrame:
    
    # Read in the data frame
    df = pd.read_csv(file_path)
    
    # Select columns to keep
    cols = list(df.columns)
    keep_cols = ['positive_sentiment', 'negative_sentiment', 'rating', 'asin.original', 'id', 'user_known', 'user_description',  'how_product_is_used', 'media', 'where_product_is_used']
    keep_cols.append(key)
    drop_cols = list(set(cols) - set(keep_cols))

    # Drop unnecessary columns
    df.drop(columns=drop_cols, inplace=True)
    df.rename(columns={key: 'key_data'}, inplace=True)

    # Explode the data
    key_data_df, key_data_list_iter_1 = explode_data(df, 'key_data')

    # Get data from AI ITER 1
    bot_replies_iter_1 = get_chatbot_responses(batch_size=80, key_data_list=key_data_list_iter_1, temperature=0)

    # Stick the dictionaries together ITER 1
    key_data_dict_1 = stick_together_dictionaries(bot_replies_iter_1)
    key_data_df['key_data_iter_1'] = key_data_df['key_data'].map(key_data_dict_1)
    key_data_list_iter_2 = sorted(list(set(key_data_df['key_data_iter_1'])))

    # ITER 2
    if len(key_data_list_iter_2) < 30:
        dict_column = 'key_data_iter_1'
    else:
        # Get data from AI ITER 2
        bot_replies_iter_2 = get_chatbot_responses(batch_size=80, key_data_list=key_data_list_iter_2, temperature=0)

        # Stick the dictionaries together ITER 2
        key_data_dict_2 = stick_together_dictionaries(bot_replies_iter_2)
        key_data_df['key_data_iter_2'] = key_data_df['key_data_iter_1'].apply(lambda x: key_data_dict_2.get(x))
        dict_column = 'key_data_iter_2'

    return key_data_df, dict_column

# %% [markdown]
# #### Improvements Expected

# %%
def get_chatbot_responses(key_data_list, batch_size=80, temperature=0.2,api_key="sk....O1LI4oq06c"):
    
    User_Prompt_1 = """
    ```Input List:``` ['cleaning','cleaning ease','adjustability' ,'adjustability of forks','adjustable length']
    """

    AI_Prompt_1 = """{
    'cleaning' : 'easy to clean',
    'cleaning ease': 'easy to clean',
    'adjustability' : 'length is adjustable',
    'adjustability of forks': 'length is adjustable',
    'adjustable length': 'length is adjustable',
    }"""

    chatbot_responses = {}
    for i in range(0, len(key_data_list), batch_size):
        # Get the current batch of up to batch_size items
        batch = key_data_list[i:i+batch_size]
        User_Prompt_2 = f"```Input List:``` {batch}"

        # Send the prompt to the chatbot and get the response
        response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo",
                    messages=[
                        {"role": "user", "content": User_Prompt_1},
                        {"role": "assistant", "content": AI_Prompt_1},
                        {"role": "user", "content": User_Prompt_2} ],
                    temperature=0.2,
                    api_key=api_key
        )
    
        # Process the response and store in the dictionary
        chatbot_responses[i] = response["choices"][0]["message"]["content"]
        print(chatbot_responses[i])
    
    return chatbot_responses

# %%
# Get data from AI ITER 1
bot_replies_iter_1 = get_chatbot_responses(batch_size=80, key_data_list=key_data_list_iter_1, temperature=0)
# Out:
# {
#     'A string to hold the pen in place': 'pen should be attached by a string to prevent loss',
#     'A way to secure the pen, quieter clicking sound': 'secure attachment for pen, quieter operation',
#     'Ability to purchase backup pens separately': 'replacement balls or boards',
#     'Addition of a string to keep the pen from being lost': 'pen should be attached by a string to prevent loss',
#     'Attach the pen to the side of the product': 'pen attachment to the product',
#     'Better design to prevent balls from falling back in holes': 'better hole design to prevent metal balls from falling out',
#     'Better functionality, attached pen': 'improved magnet functionality, attached pen',
#     'Better hole design to prevent metal balls from falling out': 'better hole design to prevent metal balls from falling out',
#     'Better magnet ball design, improved pen functionality': 'better magnet quality, improved magnet functionality',
#     'Better magnet quality': 'better magnet quality',
#     'Better magnetic pen attachment design': 'better magnetic pen attachment design',
#     'Better magnetic pen attachment, less profit-driven approach': 'better magnetic pen attachment, less profit-driven approach',
#     'Better packaging to prevent damage during shipping': 'better packaging to prevent damage during shipping',
#     'Better pen storage solution': 'better pen storage solution',
#     'Better product description with accurate size measurements': 'clear communication about the condition of the item, proper packaging',
#     'Better product quality, fix pen attachment issue': 'improved durability, better quality control, fix pen attachment issue',
#     'Better quality beads, improved design': 'more precise design with perfect patterns, improved design, better quality beads',
#     'Better quality control for magnets': 'better quality control for magnets',
#     'Better quality control, attached pen': 'better quality control, attached pen',
#     'Better quality control, replacement for damaged product': 'replacement of damaged/used product with a new one',
#     'Better quality materials, improved durability': 'more durable materials, better design to prevent rusting, improved durability, better quality control',
#     'Better quality materials, safer design': 'safer design, better quality control',
#     'Clear communication about the condition of the item, proper packaging': 'clear communication about the condition of the item, proper packaging',
#     'Connect the pen to the board': 'stylus attachment to the board, pen attachment to the board, connect the pen to the board',
#     'Connect the pen to the product': 'pen attachment to the product, connect the pen to the product',
#     'Easier to raise individual balls': 'easier to raise individual balls',
#     'Easier tracing on letter board side': 'easier tracing on letter board side',
#     'Easier-to-push magnets': 'easier-to-push magnets',
#     'Fix issue with stuck beads': 'fix issue with stuck beads',
#     'Fix the issue with balls not dropping down': 'fix the issue with balls not dropping down',
#     'Fix the issue with beads getting stuck': 'fix the issue with beads getting stuck',
#     'Improved drawing functionality': 'improved drawing functionality',
#     'Improved durability, better quality control': 'improved durability, better quality control',
#     'Improved erasability of magnets, less clunky design': 'improved erasability of magnets, less clunky design',
#     'Improved erasability of magnets, sleeker design': 'improved erasability of magnets, sleeker design',
#     'Improved magnet erasing feature, less clunky design': 'improved magnet erasing feature, less clunky design',
#     'Improved magnet functionality': 'improved magnet functionality',
#     'Improved magnet strength and functionality': 'improved magnet strength and functionality',
#     'Individual beads to respond to stylus, easier drawing experience': 'individual beads to respond to stylus, easier drawing experience',
#     'Lanyard attachment for pen': 'lanyard attachment for pen',
#     'Larger size options': 'larger size options',
#     'More durable materials, better design to prevent rusting': 'more durable materials, better design to prevent rusting',
#     'More engaging features for adults': 'more engaging features for adults',
#     'More hole pattern options for adults': 'more hole pattern options for adults',
#     'More precise design with perfect patterns': 'more precise design with perfect patterns',
#     'None mentioned': 'none mentioned',
#     'Pen attached to board with string, more color options': 'pen attached to board with string, more color options',
#     'Pen attachment mechanism': 'pen attachment mechanism',
#     'Pen attachment to notepad': 'pen attachment to notepad',
#     'Pen attachment to the board': 'pen attachment to the board',
#     'Pen attachment to the device': 'pen connectivity to device, pen attachment to the device',
#     'Pen attachment to the product': 'pen attachment to the product',
#     'Pen attachment with string': 'pen should be attached by a string',
#     'Pen connectivity to device': 'pen connectivity to device',
#     'Pen should be attached by a string': 'pen should be attached by a string to prevent loss',
#     'Pen should be attached by a string to prevent loss': 'pen should be attached by a string to prevent loss',
#     'Pens should be attached with a string': 'pens should be attached with a string to prevent loss',
#     'Pens should be attached with a string to prevent loss': 'pens should be attached with a string to prevent loss',
#     'Quieter operation': 'quieter operation',
#     'Quieter operation for plane travel': 'quieter operation for plane travel',
#     'Quieter operation, better ball mechanism': 'quieter operation, better ball mechanism',
#     'Quieter operation, better magnet strength': 'quieter operation, better magnet strength',
#     'Quieter operation, better magnetism to keep balls on board': 'quieter operation, better magnetism to keep balls on board',
#     'Quieter operation, warning about noise level on packaging': 'quieter operation, warning about noise level on packaging',
#     'Quieter volume, more engaging features for kids': 'quieter volume, more engaging features for kids',
#     'Reduced clicking noise': 'reduced clicking noise',
#     'Reduced noise levels': 'reduced noise levels',
#     'Replacement balls or boards': 'replacement balls or boards',
#     'Replacement of damaged/used product with a new one': 'replacement of damaged/used product with a new one',
#     'Replacement or refund': 'replacement or refund',
#     'Safer design, better quality control': 'safer design, better quality control',
#     'Secure attachment for pen': 'secure attachment for pen',
#     'Secure attachment of pen to board': 'secure attachment of pen to board',
#     'Securing the pen to the board': 'securing the pen to the board',
#     'Stronger magnet': 'stronger magnet',
#     'Sturdier pen and magnet, better design to prevent beads from coming up': 'sturdier pen and magnet, better design to prevent beads from coming up',
#     'Stylist to be connected to the tablet with a string or wire': 'stylus attachment mechanism',
#     'Stylus attachment mechanism': 'stylus attachment mechanism',
#     'Stylus attachment to the board': 'stylus attachment to the board'
# }

# %%
file = 'reviews_db.csv'
key = 'improvements_expected'

key_data_df, dict_column = process_data_short(file_path = file, key = key)
# Out:
# /var/folders/f6/0jn5yf2x1b319g8j96pnjbwh0000gn/T/ipykernel_54518/474324282.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column_name][i] = ast.literal_eval(dataframe[column_name][i])
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[16], line 4
#       1 file = 'reviews_db.csv'
#       2 key = 'improvements_expected'
# ----> 4 key_data_df, dict_column = process_data_short(file_path = file, key = key)
#
# Cell In[14], line 207, in process_data_short(file_path, key)
#     204 key_data_df, key_data_list_iter_1 = explode_data(df, 'key_data')
#     206 # Get data from AI ITER 1
# --> 207 bot_replies_iter_1 = get_chatbot_responses(batch_size=80, key_data_list=key_data_list_iter_1, temperature=0)
#     209 # Stick the dictionaries together ITER 1
#     210 key_data_dict_1 = stick_together_dictionaries(bot_replies_iter_1)
#
# Cell In[14], line 65, in get_chatbot_responses(key_data_list, batch_size, temperature)
#      62 User_Prompt_2 = f"```Input List:``` {batch}"
#      64 # Send the prompt to the chatbot and get the response
# ---> 65 response = openai.ChatCompletion.create(
#      66             model="gpt-3.5-turbo",
#      67             messages=[
#      68                 {"role": "user", "content": User_Prompt_1},
#      69                 {"role": "assistant", "content": AI_Prompt_1},
#      70                 {"role": "user", "content": User_Prompt_2} ],
#      71             temperature=0.2
#      72 )
#      74 # Process the response and store in the dictionary
#      75 chatbot_responses[i] = response["choices"][0]["message"]["content"]
#
# File ~/anaconda3/envs/oaie/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/anaconda3/envs/oaie/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/anaconda3/envs/oaie/lib/python3.10/site-packages/openai/api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#    (...)
#     224         request_timeout=request_timeout,
#     225     )
# --> 226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~/anaconda3/envs/oaie/lib/python3.10/site-packages/openai/api_requestor.py:620, in APIRequestor._interpret_response(self, result, stream)
#     612     return (
#     613         self._interpret_response_line(
#     614             line, result.status_code, result.headers, stream=True
#     615         )
#     616         for line in parse_stream(result.iter_lines())
#     617     ), True
#     618 else:
#     619     return (
# --> 620         self._interpret_response_line(
#     621             result.content.decode("utf-8"),
#     622             result.status_code,
#     623             result.headers,
#     624             stream=False,
#     625         ),
#     626         False,
#     627     )
#
# File ~/anaconda3/envs/oaie/lib/python3.10/site-packages/openai/api_requestor.py:683, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     681 stream_error = stream and "error" in resp.data
#     682 if stream_error or not 200 <= rcode < 300:
# --> 683     raise self.handle_error_response(
#     684         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685     )
#     686 return resp
#
# AuthenticationError: <empty message>

# %%
improvements_expected_df_heatmap = key_data_df.copy()
improvements_expected_df_graph = key_data_df.copy()
dict_column_heatmap = dict_column
dict_column_graph = dict_column

# %%
# Data Processing, final step
weighted_improvements_expected_df_heatmap = get_weighted_results_heatmap(dataframe=improvements_expected_df_heatmap, data_column_name=dict_column_heatmap, aisin_column='asin.original')

# %%
weighted_improvements_expected_df_heatmap['type'] = 'Improvement'
weighted_improvements_expected_df_heatmap.to_csv('weighted_improvements_expected_df_heatmap.csv', index=False)

# %%
weighted_improvements_expected_df_graph = get_weighted_results_graph(dataframe=improvements_expected_df_graph, data_column_name=dict_column_graph, aisin_column='asin.original')

# %%
weighted_improvements_expected_df_graph = weighted_improvements_expected_df_graph.explode(column = 'asin.original')

# %%
weighted_improvements_expected_df_graph['type'] = 'Improvement'
weighted_improvements_expected_df_graph.to_csv('weighted_improvements_expected_df_graph.csv', index=False)

# %% [markdown]
# #### Issues Identified

# %%
file = 'reviews_db.csv'
key = 'issues_identified'

key_data_df, dict_column = process_data_short(file_path = file, key = key)
# Out:
# /var/folders/f6/0jn5yf2x1b319g8j96pnjbwh0000gn/T/ipykernel_54518/1540522487.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column_name][i] = ast.literal_eval(dataframe[column_name][i])
# {
#     'A bit loud and rattly at first': 'noisy at first',
#     'Balls not coming up as they are supposed to': 'malfunctioning balls',
#     'Balls not coming up as they should': 'malfunctioning balls',
#     'Balls not staying up, balls getting stuck, detachable pen': 'malfunctioning balls and detachable pen',
#     'Balls not working properly, detachable pen': 'malfunctioning balls and detachable pen',
#     'Beads get stuck towards the bottom': 'beads getting stuck',
#     'Beads getting stuck': 'beads getting stuck',
#     'Beads getting stuck at the bottom': 'beads getting stuck',
#     'Beads getting stuck, decreased functionality over time': 'beads getting stuck and decreased functionality over time',
#     'Can be loud': 'noisy',
#     'Can get annoying over time': 'annoying over time',
#     "Chipped holes, metal balls won't stay up": 'chipped holes and metal balls not staying up',
#     'Clicking noise can be annoying': 'annoying clicking noise',
#     'Clicking sound may bother some users, pen could be easily misplaced': 'annoying clicking sound and easily misplaced pen',
#     'Clicking sound may bother some users, pen could easily be misplaced': 'annoying clicking sound and easily misplaced pen',
#     'Coating on pen came off and left shards on the board': 'pen coating came off and left shards on the board',
#     'Coating on pen came off, leaving shards on the board': 'pen coating came off and left shards on the board',
#     'Defective balls not staying up': 'defective balls not staying up',
#     'Defective item, missing magnet in pen': 'defective item with missing magnet in pen',
#     'Design limitations with 19x20 holes': 'design limitations with 19x20 holes',
#     'Detachable pen can be misplaced': 'easily misplaced detachable pen',
#     'Detachable pen is easy to misplace': 'easily misplaced detachable pen',
#     'Difficult to draw with': 'difficult to draw with',
#     'Difficult to raise individual balls, prevents writing in braille': 'difficult to raise individual balls and prevents writing in braille',
#     'Difficulty for young children to push beads down': 'difficulty for young children to push beads down',
#     'Easily disrupted by others': 'easily disrupted by others',
#     'Frequent fighting among preschoolers': 'frequent fighting among preschoolers',
#     'Frustration with balls not dropping down on drawing side': 'frustration with balls not dropping down on drawing side',
#     'Frustration with drawing shapes': 'frustration with drawing shapes',
#     'Kids were not interested, annoying for others on the plane': 'kids were not interested and annoying for others on the plane',
#     'Kids were not interested, loud volume was annoying for others on the plane': 'kids were not interested and loud volume was annoying for others on the plane',
#     'Limited hole pattern for creating perfect designs': 'limited hole pattern for creating perfect designs',
#     'Limited hole pattern options': 'limited hole pattern options',
#     'Lost pen due to lack of attachment': 'lost pen due to lack of attachment',
#     'Lost pen renders device useless': 'lost pen renders device useless',
#     'Lost pen renders the product useless': 'lost pen renders product useless',
#     'Lost pen renders toy useless': 'lost pen renders toy useless',
#     'Lost pen, rendering product useless': 'lost pen renders product useless',
#     'Loud and bothersome for plane travel': 'loud and bothersome for plane travel',
#     'Loud and rattly at first': 'noisy and rattly at first',
#     'Loud noise': 'loud noise',
#     'Loud noise level, ball getting stuck': 'loud noise level and ball getting stuck',
#     'Loud noise level, ball getting stuck frequently': 'loud noise level and frequent ball getting stuck',
#     "Loud operation, balls don't always stay on board": 'loud operation and balls not staying on board',
#     'Loud operation, balls falling off the board': 'loud operation and balls falling off the board',
#     'Loudness': 'loudness',
#     "Magnet balls don't stay up when using the pen, product is useless": 'magnet balls not staying up when using the pen and product being useless',
#     "Magnet doesn't stay up": 'magnet not staying up',
#     'Magnetic balls keep falling back in their holes': 'magnetic balls keep falling back in their holes',
#     'Magnets are not easily erased, clunkier than expected': 'magnets not easily erased and clunkier than expected',
#     'Magnets are not easily erased, clunky design': 'magnets not easily erased and clunky design',
#     'Magnets can be hard to push down': 'magnets hard to push down',
#     'Magnets not working properly': 'malfunctioning magnets',
#     "Magnets sometimes get stuck and won't reset": 'magnets getting stuck and not resetting',
#     'Metal balls falling out of some holes': 'metal balls falling out of some holes',
#     'Metal balls falling out of some holes.': 'metal balls falling out of some holes',
#     'None mentioned': 'no issues mentioned',
#     'Not suitable for all users': 'not suitable for all users',
#     'Pen and magnet easily breakable, beads come up too easily': 'easily breakable pen and magnet and beads coming up too easily',
#     'Pen broke within 10 minutes, potential safety hazard for children': 'pen broke within 10 minutes and potential safety hazard for children',
#     'Pen can be easily lost without a string': 'pen easily lost without a string',
#     'Pen easily lost, frustrating for kids': 'pen easily lost and frustrating for kids',
#     'Pen gets dropped during car use': 'pen gets dropped during car use',
#     'Pen gets lost easily': 'pen gets lost easily',
#     'Pen gets lost easily, limited color options': 'pen gets lost easily and limited color options',
#     'Pen getting dropped while using in the car': 'pen getting dropped while using in the car',
#     'Pen is not attached and can be easily lost': 'pen not attached and easily lost',
#     'Pen is not attached and was lost on the first day': 'pen not attached and lost on the first day',
#     'Pen is not attached to the product, causing inconvenience': 'pen not attached to the product and causing inconvenience',
#     'Pen not connected to the board': 'pen not connected to the board',
#     'Pen not securely attached to board': 'pen not securely attached to board',
#     'Pen not securely attached to board, loud noise when shaking': 'pen not securely attached to board and loud noise when shaking',
#     'Pen was lost quickly': 'pen was lost quickly',
#     'Pens are too easy to lose': 'pens too easy to lose',
#     'Pens get lost easily': 'pens get lost easily',
#     'Poor magnetic pen attachment design, having to buy replacement pens': 'poor magnetic pen attachment design and having to buy replacement pens',
#     'Poor magnetic pen attachment, profit-driven approach': 'poor magnetic pen attachment and profit-driven approach',
#     'Product arrived slightly damaged': 'product arrived slightly damaged',
#     'Product can get annoying over time': 'product can get annoying over time',
#     "Product doesn't work, pen attachment doesn't pull up magnets": 'product not working and pen attachment not pulling up magnets'
# }
# {
#     'Product size is smaller than expected': 'size is smaller than expected',
#     'Received a used item instead of a new one, no packaging': 'received a used item instead of a new one, no packaging',
#     'Received damaged/used product instead of new': 'received a damaged/used product instead of new',
#     'Rust formation even with small spills, easily destroyed': 'rusts easily, not durable',
#     'Rusts easily, not durable, not worth the money': 'rusts easily, not durable, not worth the money',
#     'Slightly loud': 'slightly loud',
#     'Slightly noisy': 'slightly noisy',
#     'Some holes are slightly smaller, causing metal balls to fall out': 'some holes are slightly smaller, causing metal balls to fall out',
#     'Some magnets are hard to fit': 'some magnets are hard to fit',
#     'Spots on magnet board stopped sticking or functioning altogether': 'spots on magnet board stopped sticking or functioning altogether',
#     'Stylist is too easy to lose': 'stylus is too easy to lose',
#     'Stylus can get lost': 'stylus can get lost',
#     'Stylus getting lost': 'stylus getting lost',
#     'Too loud for airplane travel': 'too loud for airplane travel',
#     'Too loud for long journeys': 'too loud for long journeys',
#     'Toy is very loud and not conducive to quiet environments': 'toy is very loud and not conducive to quiet environments',
#     'Tricky to use for strengthening pencil grip, strong magnet makes it difficult to trace letters': 'tricky to use for strengthening pencil grip, strong magnet makes it difficult to trace letters',
#     'Very loud, not suitable for quiet environments': 'very loud, not suitable for quiet environments'
# }
# {
#     'annoying clicking noise': 'makes an annoying clicking noise',
#     'annoying clicking sound and easily misplaced pen': 'pen is easily misplaced and makes an annoying clicking sound',
#     'annoying over time': 'can become annoying over time',
#     'beads getting stuck': 'beads can get stuck',
#     'beads getting stuck and decreased functionality over time': 'beads can get stuck and functionality can decrease over time',
#     'chipped holes and metal balls not staying up': 'holes can chip and metal balls may not stay up',
#     'defective balls not staying up': 'balls may be defective and not stay up',
#     'defective item with missing magnet in pen': 'item may be defective with a missing magnet in the pen',
#     'design limitations with 19x20 holes': 'design has limitations with only 19x20 holes',
#     'difficult to draw with': 'difficult to draw with',
#     'difficult to raise individual balls and prevents writing in braille': 'difficult to raise individual balls and prevents writing in braille',
#     'difficulty for young children to push beads down': 'difficult for young children to push beads down',
#     'easily breakable pen and magnet and beads coming up too easily': 'pen and magnet are easily breakable and beads may come up too easily',
#     'easily disrupted by others': 'can be easily disrupted by others',
#     'easily misplaced detachable pen': 'pen is easily misplaced because it is detachable',
#     'frequent fighting among preschoolers': 'frequent fighting among preschoolers',
#     'frustration with balls not dropping down on drawing side': 'frustration with balls not dropping down on drawing side',
#     'frustration with drawing shapes': 'frustration with drawing shapes',
#     'kids were not interested and annoying for others on the plane': 'kids were not interested and it was annoying for others on the plane',
#     'kids were not interested and loud volume was annoying for others on the plane': 'kids were not interested and the loud volume was annoying for others on the plane',
#     'limited hole pattern for creating perfect designs': 'limited hole pattern for creating perfect designs',
#     'limited hole pattern options': 'limited hole pattern options',
#     'lost pen due to lack of attachment': 'pen is easily lost due to lack of attachment',
#     'lost pen renders device useless': 'losing the pen renders the device useless',
#     'lost pen renders product useless': 'losing the pen renders the product useless',
#     'lost pen renders toy useless': 'losing the pen renders the toy useless',
#     'loud and bothersome for plane travel': 'loud and bothersome for plane travel',
#     'loud noise': 'makes a loud noise',
#     'loud noise level and ball getting stuck': 'makes a loud noise and balls can get stuck',
#     'loud noise level and frequent ball getting stuck': 'makes a loud noise and balls frequently get stuck',
#     'loud operation and balls falling off the board': 'operation is loud and balls can fall off the board',
#     'loud operation and balls not staying on board': 'operation is loud and balls may not stay on the board',
#     'loudness': 'is loud',
#     'magnet balls not staying up when using the pen and product being useless': 'magnet balls may not stay up when using the pen, rendering the product useless',
#     'magnet not staying up': 'magnet may not stay up',
#     'magnetic balls keep falling back in their holes': 'magnetic balls keep falling back in their holes',
#     'magnets getting stuck and not resetting': 'magnets can get stuck and not reset',
#     'magnets hard to push down': 'magnets are hard to push down',
#     'magnets not easily erased and clunkier than expected': 'magnets are not easily erased and the design is clunkier than expected',
#     'magnets not easily erased and clunky design': 'magnets are not easily erased and the design is clunky',
#     'malfunctioning balls': 'balls may malfunction',
#     'malfunctioning balls and detachable pen': 'balls may malfunction and the pen is detachable',
#     'malfunctioning magnets': 'magnets may malfunction',
#     'metal balls falling out of some holes': 'metal balls may fall out of some holes',
#     'no issues mentioned': 'no issues mentioned',
#     'noisy': 'is noisy',
#     'noisy and rattly at first': 'is noisy and rattly at first',
#     'noisy at first': 'is noisy at first',
#     'not suitable for all users': 'not suitable for all users',
#     'pen broke within 10 minutes and potential safety hazard for children': 'pen broke within 10 minutes and may be a potential safety hazard for children',
#     'pen coating came off and left shards on the board': 'pen coating came off and left shards on the board',
#     'pen easily lost and frustrating for kids': 'pen is easily lost and frustrating for kids',
#     'pen easily lost without a string': 'pen is easily lost without a string',
#     'pen gets dropped during car use': 'pen gets dropped during car use',
#     'pen gets lost easily': 'pen gets lost easily',
#     'pen gets lost easily and limited color options': 'pen gets lost easily and there are limited color options',
#     'pen getting dropped while using in the car': 'pen gets dropped while using in the car',
#     'pen not attached and easily lost': 'pen is not attached and easily lost',
#     'pen not attached and lost on the first day': 'pen is not attached and was lost on the first day',
#     'pen not attached to the product and causing inconvenience': 'pen is not attached to the product and causing inconvenience',
#     'pen not connected to the board': 'pen is not connected to the board',
#     'pen not securely attached to board': 'pen is not securely attached to the board',
#     'pen not securely attached to board and loud noise when shaking': 'pen is not securely attached to the board and makes a loud noise when shaking',
#     'pen was lost quickly': 'pen was lost quickly',
#     'pens get lost easily': 'pens get lost easily',
#     'pens too easy to lose': 'pens are too easy to lose',
#     'poor magnetic pen attachment and profit-driven approach': 'poor magnetic pen attachment and a profit-driven approach',
#     'poor magnetic pen attachment design and having to buy replacement pens': 'poor magnetic pen attachment design and having to buy replacement pens',
#     'product arrived slightly damaged': 'product arrived slightly damaged',
#     'product can get annoying over time': 'product can become annoying over time',
#     'product not working and pen attachment not pulling up magnets': 'product is not working and the pen attachment is not pulling up magnets',
#     'received a damaged/used product instead of new': 'received a damaged/used product instead of a new one, with no packaging',
#     'received a used item instead of a new one, no packaging': 'received a used item instead of a new one, with no packaging',
#     'rusts easily, not durable': 'rusts easily and is not durable',
#     'rusts easily, not durable, not worth the money': 'rusts easily, is not durable, and not worth the money',
#     'size is smaller than expected': 'size is smaller than expected',
#     'slightly loud': 'is slightly loud',
#     'slightly noisy': 'is slightly noisy',
#     'some holes are slightly smaller, causing metal balls to fall out': 'some holes are slightly smaller, causing metal balls to fall out',
#     'some magnets are hard to fit': 'some magnets are hard to fit',
# }
# {
#     'spots on magnet board stopped sticking or functioning altogether': 'magnet board not working properly',
#     'stylus can get lost': 'stylus is prone to getting lost',
#     'stylus getting lost': 'stylus is prone to getting lost',
#     'stylus is too easy to lose': 'stylus is prone to getting lost',
#     'too loud for airplane travel': 'too loud for use on airplanes',
#     'too loud for long journeys': 'too loud for use on long journeys',
#     'toy is very loud and not conducive to quiet environments': 'too loud for quiet environments',
#     'tricky to use for strengthening pencil grip, strong magnet makes it difficult to trace letters': 'difficult to use for strengthening pencil grip and tracing letters due to strong magnet',
#     'very loud, not suitable for quiet environments': 'too loud for quiet environments',
# }

# %%
issues_identified_df_heatmap = key_data_df.copy()
issues_identified_df_graph = key_data_df.copy()
dict_column_heatmap = dict_column
dict_column_graph = dict_column

# %%
# Data Processing, final step
weighted_issues_identified_df_heatmap = get_weighted_results_heatmap(dataframe=issues_identified_df_heatmap, data_column_name=dict_column_heatmap, aisin_column='asin.original')

# %%
weighted_issues_identified_df_heatmap['type'] = 'Issue'
weighted_issues_identified_df_heatmap.to_csv('weighted_issues_identified_df_heatmap.csv', index=False)

# %%
weighted_issues_identified_df_graph = get_weighted_results_graph(dataframe=issues_identified_df_graph, data_column_name=dict_column_graph, aisin_column='asin.original')

# %%
weighted_issues_identified_df_graph = weighted_issues_identified_df_graph.explode(column = 'asin.original')

# %%
weighted_issues_identified_df_graph['type'] = 'Issue'
weighted_issues_identified_df_graph.to_csv('weighted_issues_identified_df_graph.csv', index=False)

# %% [markdown]
# #### Product Facts

# %%
file = 'reviews_db.csv'
key = 'observed_technical_facts'

key_data_df, dict_column = process_data_short(file_path = file, key = key)
# Out:
# {
#     '10 balls on drawing side not dropping down': 'balls not dropping down',
#     'Balls not staying up, balls getting stuck, detachable pen': 'balls not staying up, getting stuck',
#     'Balls not staying up, some getting stuck, detachable pen': 'balls not staying up, getting stuck',
#     'Beads and pen functionality': 'pen and beads work well',
#     'Beads cannot come out of the item': 'beads cannot be removed',
#     'Beads stay in place, easy to use': 'beads stay in place and are easy to use',
#     'Beads stick well': 'beads stick well',
#     'Beads that respond to stylus, groups of four beads surface': 'beads respond to stylus, groups of four',
#     'Beads toy': 'toy with beads',
#     'Beads, functionality': 'beads work well',
#     'Beads, pen, clicking sound': 'pen clicks when used with beads',
#     'Black background, silver balls': 'black background with silver balls',
#     'Board and pen': 'board and pen',
#     'Board with holes, pen with cord': 'board with holes, pen with cord',
#     "Chipped holes, metal balls won't stay up": 'chipped holes, balls not staying up',
#     'Coating on pen came off after one day of use': 'pen coating came off after one day',
#     'Comes with a pen for drawing on the toy': 'comes with pen for drawing',
#     'Contains lots of pieces, all contained in one board': 'many pieces in one board',
#     'Creates patterns, colorful, durable': 'creates patterns, colorful and durable',
#     'Defective balls': 'defective balls',
#     'Drawing board with pen': 'drawing board with pen',
#     'Easy to draw on, satisfying to clear off, pencil snaps easily into it and stays put': 'easy to draw on and clear off, pencil snaps in and stays put',
#     'Easy to play with, satisfying': 'easy and satisfying to play with',
#     'Easy to use, pencil snaps easily into it and stays put': 'easy to use, pencil snaps in and stays put',
#     'Includes stylus for drawing and erasing': 'includes stylus for drawing and erasing',
#     'Loud noise level, ball getting stuck': 'loud noise, ball getting stuck',
#     'Loud operation': 'loud operation',
#     'Loud operation, 19x20 hole pattern': 'loud operation, 19x20 holes',
#     'Loud volume': 'loud volume',
#     'Magnet': 'magnet',
#     'Magnet balls, pen': 'magnet balls and pen',
#     'Magnet board for facilitating grasp patterns and hand-eye coordination': 'magnet board for hand-eye coordination',
#     'Magnet pens, nylon thread modification': 'magnet pens with nylon thread modification',
#     'Magnetic back, detachable pen': 'magnetic back with detachable pen',
#     'Magnetic balls, holes': 'magnetic balls and holes',
#     'Magnetic beads inside, makes loud rattling and clacking sounds': 'loud rattling and clacking sounds from magnetic beads inside',
#     'Magnetic beads inside, noisy clacking sounds': 'noisy clacking sounds from magnetic beads inside',
#     'Magnetic board': 'magnetic board',
#     'Magnetic board, metal balls': 'magnetic board with metal balls',
#     'Magnetic board, metal rods, attached pen': 'magnetic board with metal rods and attached pen',
#     'Magnetic drawing board': 'magnetic drawing board',
#     'Magnetic drawing board and letter board': 'magnetic drawing and letter board',
#     'Magnetic drawing board with pen': 'magnetic drawing board with pen',
#     'Magnetic drawing board with pen and beads': 'magnetic drawing board with pen and beads',
#     'Magnetic drawing board with tracing lines for letters': 'magnetic drawing board with tracing lines for letters',
#     'Magnetic drawing board, pen': 'magnetic drawing board with pen',
#     'Magnetic drawing tool': 'magnetic drawing tool',
#     'Magnetic notepad with detachable pen': 'magnetic notepad with detachable pen',
#     'Magnetic pen': 'magnetic pen',
#     'Magnetic pen attachment': 'magnetic pen attachment',
#     'Magnetic pencil': 'magnetic pencil',
#     'Magnetic pens, nylon thread modification': 'magnetic pens with nylon thread modification',
#     'Magnetic toy': 'magnetic toy',
#     'Magnetic toy with pop-up feature': 'magnetic toy with pop-up feature',
#     'Makes a unique soft noise, easy to figure out': 'unique soft noise, easy to figure out',
#     'Marble maze pad with sound effects': 'marble maze pad with sound effects',
#     'Marble push game, sound effects': 'marble push game with sound effects',
#     'Marble push toy with sound effects': 'marble push toy with sound effects',
#     'Marbles and magnets for tactile stimulation, letters for tracing': 'marbles and magnets for tactile stimulation and tracing letters',
#     'Metal beads that move around and make a shaking noise, cards with instructions for making different designs': 'metal beads that move and make noise, cards with instructions for designs',
#     'Missing magnet in pen': 'missing magnet in pen',
#     'Multiple pieces, contained in one board': 'many pieces in one board',
#     'Negligible sound, no external energy source required': 'no sound, no external energy required',
#     'No technical facts mentioned': 'no technical facts mentioned',
#     'No technical facts mentioned.': 'no technical facts mentioned',
#     'Pen functionality': 'pen functionality',
#     'Pen not connected to device': 'pen not connected to device',
#     'Pen with spring and magnet': 'pen with spring and magnet',
#     'Portable, suggested drawings, mess-free': 'portable, suggested drawings, mess-free',
#     'Secure pen snap, magnetic holes, eraser feature': 'secure pen snap, magnetic holes, eraser feature',
#     'Sensory beads that can be pushed down': 'sensory beads that can be pushed down',
#     'Sensory features': 'sensory features',
#     'Sensory toy with beads that can be pushed down': 'sensory toy with push-down beads',
#     'Size of the product': 'product size',
#     'Slots for pushing balls, attached stylus': 'slots for pushing balls, attached stylus',
#     'Strong magnetic field': 'strong magnetic field',
#     'Strong magnetic field, easy to use': 'strong magnetic field, easy to use',
#     'Tablet and stylist': 'tablet and stylus',
#     'Tablet with rusty balls inside': 'tablet with rusty balls inside',
#     'Tablet with small balls that rust easily': 'tablet with small balls that rust easily',
# }
# {
#     'Tablet-compatible, includes stylist': 'compatible with tablet and includes stylus',
#     'Tactile drawing board with raised balls': 'drawing board with raised balls for tactile feedback',
#     'Toy with little balls and pen': 'toy with small balls and pen',
# }
# I'm sorry, I cannot provide an output for this input as it is a list of various features and issues related to different products. Please provide more context or specify which product you are referring to.
# Traceback (most recent call last):
#
#   File ~/anaconda3/envs/oaie/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3505 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[64], line 4
#     key_data_df, dict_column = process_data_short(file_path = file, key = key)
#
#   Cell In[20], line 223 in process_data_short
#     key_data_dict_2 = stick_together_dictionaries(bot_replies_iter_2)
#
#   Cell In[20], line 85 in stick_together_dictionaries
#     dict_obj = eval(placeholder_dict[key])
#
#   File <string>:1
#     I'm sorry, I cannot provide an output for this input as it is a list of various features and issues related to different products. Please provide more context or specify which product you are referring to.
#      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
 
    # Read in the data frame
    df = pd.read_csv(file_path)
    
    # Select columns to keep
    cols = list(df.columns)
    keep_cols = ['positive_sentiment', 'negative_sentiment', 'rating', 'asin.original', 'id', 'user_known', 'user_description',  'how_product_is_used', 'media', 'where_product_is_used']
    keep_cols.append(key)
    drop_cols = list(set(cols) - set(keep_cols))

    # Drop unnecessary columns
    df.drop(columns=drop_cols, inplace=True)
    df.rename(columns={key: 'key_data'}, inplace=True)

# %%
product_facts_df_heatmap = key_data_df.copy()
product_facts_df_graph = key_data_df.copy()
dict_column_heatmap = dict_column
dict_column_graph = dict_column

# %%
# Data Processing, final step
weighted_product_facts_df_heatmap = get_weighted_results_heatmap(dataframe=product_facts_df_heatmap, data_column_name=dict_column_heatmap, aisin_column='asin.original')

# %%
weighted_product_facts_df_heatmap['type'] = 'Fact'
weighted_product_facts_df_heatmap.rename(columns={'observed_technical_facts': 'product_facts'}, inplace=True)
weighted_product_facts_df_heatmap.to_csv('weighted_product_facts_df_heatmap.csv', index=False)

# %%
weighted_product_facts_df_graph = get_weighted_results_graph(dataframe=product_facts_df_graph, data_column_name=dict_column_graph, aisin_column='asin.original')

# %%
weighted_product_facts_df_graph = weighted_product_facts_df_graph.explode(column = 'asin.original')

# %%
weighted_product_facts_df_graph['type'] = 'Fact'
weighted_product_facts_df_heatmap.rename(columns={'observed_technical_facts': 'product_facts'}, inplace=True)
weighted_product_facts_df_graph.to_csv('weighted_product_facts_df_graph.csv', index=False)

# %%
run_clustering_script(database = 'postgresql://postgres:mysecretpassword@localhost/postgres')
